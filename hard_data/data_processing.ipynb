# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import json
import plotly.express as px

# %%
with open('paris/paris.json') as json_file:
    data = json.load(json_file)
    
dfmetro = pd.DataFrame(data["stations"]).T

lines = list(data["lines"].keys())

for line in lines:
    dfline = dfmetro[dfmetro["line"].apply(lambda x: line in x)]
    print(line, ":", len(dfline))
# Out:
# 1 : 25
# 2 : 25
# 3 : 25
# 3bis : 4
# 4 : 29
# 5 : 22
# 6 : 28
# 7 : 38
# 7bis : 8
# 8 : 38
# 9 : 37
# 10 : 23
# 11 : 19
# 12 : 31
# 13 : 32
# 14 : 21

# %%
line = "14"

dfline = dfmetro[dfmetro["line"].apply(lambda x: line in x)]
dfline.head()
# Out:
#                          name               line               coords
# Cha1471114           Châtelet  [1, 4, 7, 11, 14]  [48 51 31, 2 20 50]
# GarLyo114        Gare de Lyon            [1, 14]  [48 50 41, 2 22 27]
# SaiLaz3121314    Saint-Lazare    [3, 12, 13, 14]  [48 52 32, 2 19 34]
# Ber614                  Bercy            [6, 14]  [48 50 26, 2 22 46]
# MaiBla714      Maison Blanche            [7, 14]  [48 49 20, 2 21 31]

# %%
line = "13"

def plot_line(line, dfmetro):
    
    dfline = dfmetro[dfmetro["line"].apply(lambda x: line in x)].copy()
    
    def dms_to_decimal(dms):
        deg, minutes, seconds = map(float, dms.split())
        return deg + minutes / 60 + seconds / 3600
    
    dfline["Lat"], dfline["Long"] = dfline["coords"].apply(lambda x : dms_to_decimal(x[0])), dfline["coords"].apply(lambda x : dms_to_decimal(x[1]))
    dfline["color"] = data["lines"][line]["color"]
    
    zoom = 9  
    color_map = {c: c for c in dfline["color"].unique()}
    
    fig = px.scatter_map(
        dfline,
        lat="Lat",
        lon="Long",
        hover_name="name",
        color="color",
        color_discrete_map=color_map,
        zoom=zoom,
        center=dict(lat=dfline.Lat.mean(), lon=dfline.Long.mean()),
        map_style="open-street-map",
    )
    
    fig.update_traces(marker=dict(size=10))
    fig.update_layout(showlegend=False)

    fig.show()
    
plot_line(line, dfmetro)

# %%
def plot_whole(dfmetro):
    
    dfmet = dfmetro.copy()
    
    def dms_to_decimal(dms):
        deg, minutes, seconds = map(float, dms.split())
        return deg + minutes / 60 + seconds / 3600
    
    dfmet["Lat"], dfmet["Long"] = dfmet["coords"].apply(lambda x : dms_to_decimal(x[0])), dfmet["coords"].apply(lambda x : dms_to_decimal(x[1]))
    dfmet["color"] = dfmet["line"].apply(lambda x : data["lines"][x[0]]["color"])
    
    #marker = {"color" : "green", "symbol" : "circle", "size" : 12}
    zoom = 9  
    color_map = {c: c for c in dfmet["color"].unique()}
    
    fig = px.scatter_map(
        dfmet,
        lat="Lat",
        lon="Long",
        hover_name="name",
        color="color",
        color_discrete_map=color_map,
        zoom=zoom,
        center=dict(lat=dfmet.Lat.mean(), lon=dfmet.Long.mean()),
        map_style="open-street-map",
    
    )

    fig.update_traces(marker=dict(size=10))
    fig.update_layout(showlegend=False)
    fig.show()
    
plot_whole(dfmetro)
